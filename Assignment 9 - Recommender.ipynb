# %%
import pandas as pd
import numpy as np

# %%
#download the class movie reviews from here:
#https://docs.google.com/spreadsheets/d/17rCJzmWxqvAu9rkpkgt4ToccIlY4A1Ffuu1W9X3B8Ag/
#then read that in as a pandas dataframe

# %%
M = pd.read_csv("/users/pisonwaters/desktop/Movie Reviews - Sheet1.csv", index_col='Name')

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %%
#Question 1: What movie is most Similar to 'The fault in our stars' (60 pts)

# %%
recs = get_recs('The Fault in Our Stars', M, 17)

# %%
recs[:17]
# Out:
# [('Interstellar', 0.25035799093321581),
#  ('Malificent', 0.21375403213728197),
#  ('Divergent', 0.17470709093502157),
#  ('How to Train your Dragon 2', 0.15769576025447332),
#  ('Guardians of the Galaxy', 0.14815495894813277),
#  ('Unbroken', 0.075201321328153076),
#  ('Gone Girl', 0.069028758717867858),
#  ('The Lego Movie', 0.059899519128956427),
#  ('The Hunger Games: Mockingjay - Part 1', 0.059150717691497795),
#  ('Transformers', 0.010345558567015559),
#  ('The Hobbit', -0.0064260743251112178),
#  ('300: Rise of an Empire', -0.046920362656838306),
#  ('Godzilla', -0.047355933368302405),
#  ('Big Hero 6', -0.056614041247155064),
#  ('American Sniper', -0.12571904015492416)]

# %%
#The movie most similar to 'The Fault in Our Stars' is 'Interstellar' with a correlation of 0.25

# %%
#Question 2: Which movie(s) would you most like to see, based on your classmates experience? (40 pts)

# %%
#the movies I've seen
my_ratings = M.ix['Yinka Adeyemo'].dropna()
#the movie I've rated the highest
my_ratings.sort(ascending=False)
#the name of the movie I've rated the highest
fav_movie = my_ratings.index[0]

# %%
fav_movie
# Out:
# '300: Rise of an Empire'

# %%
#Question 3: Bonus Question... For all the movies you haven't seen, can you predict how you'd rate them using your the class reviews? (10 pts)

# %%
my_ratings
# Out:
# 300: Rise of an Empire                    4
# How to Train your Dragon 2                4
# Big Hero 6                                4
# The Hobbit                                4
# Guardians of the Galaxy                   4
# American Sniper                           4
# The Hunger Games: Mockingjay - Part 1   NaN
# The Lego Movie                          NaN
# Transformers                            NaN
# Malificent                              NaN
# Godzilla                                NaN
# Interstellar                            NaN
# Gone Girl                               NaN
# Divergent                               NaN
# The Fault in Our Stars                  NaN
# Unbroken                                NaN
# Name: Yinka Adeyemo, dtype: float64

# %%
M
# Out:
#                     American Sniper  The Hunger Games: Mockingjay - Part 1  \
# Name
# Aarti Jaiswal                   4.0                                    NaN
# Aditya Dharmasagar              5.0                                    NaN
# Adrian Cavallaris               NaN                                    4.0
# Ahmed Muheebuddin               5.0                                    NaN
# Aishwarya reddy                 NaN                                    3.0
# Akhilesh                        NaN                                    NaN
# Andrew Webb                     4.0                                    3.0
# Anirudh                         3.0                                    4.0
# Anirudh Thota                   NaN                                    3.0
# anurag                          4.0                                    NaN
# Anusha Putta                    NaN                                    NaN
# ...

# %%
M.describe()
# Out:
#        American Sniper  The Hunger Games: Mockingjay - Part 1  \
# count        62.000000                              69.000000
# mean          4.153226                               3.318841
# std           0.721955                               0.874353
# min           3.000000                               1.000000
# 25%           4.000000                               3.000000
# 50%           4.000000                               3.000000
# 75%           5.000000                               4.000000
# max           5.000000                               5.000000
#
#        Guardians of the Galaxy  The Lego Movie  The Hobbit  Transformers  \
# count                79.000000       56.000000   82.000000     84.000000
# mean                  3.892405        3.428571    4.096341      3.696429
# std                   0.807302        1.006473    0.844363      1.179692
# min                   2.000000        1.000000    1.000000      1.000000
# ...

# %%
# for the movies that I have not watched yet, I can use the above mean figure to predict my ratings.
