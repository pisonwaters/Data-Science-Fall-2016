# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("/Users/pisonwaters/desktop/train.csv")

# %%
# !ls../data
# Out:
# /bin/sh: ls../data: No such file or directory

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
### The variables are both continuos plus categorical. For example, the age plus the fare are both continuos whereas the gender plus name are categorical.

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %%
### Sex is categorical.

# %%
df.Sex.value_counts().plot(kind ='bar')

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
### Three are no missing values in "Sex"

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
### To know the distribution of fares, we need to run the histogram function

# %%
df.Fare.hist(bins=5)

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
##There are no null fares

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# ...
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Length: 891, dtype: int64

# %%
### PassengerID is continuous as shown in the count above.

# %%
### To know how many people survived, we can use the survived variable and group them where zero represents those who died and I otherwise
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %%
## We may also want to know the number of passengers who embarked. This is also categorical and not continuos
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# dtype: int64

# %%
## We can also find out how many female passengers actually embarked as follows:
df[df.Sex =='female'].Embarked.value_counts()
# Out:
# S    203
# C     73
# Q     36
# dtype: int64

# %%
### We can also find out the number of NaN in the cabin who emabarked as follows:
df[df.Cabin.isnull()].Embarked.value_counts().plot(kind = 'bar')

# %%
### This tells us how many people above 35 years old survived and how many died.

df[df.Age == 35].Survived.value_counts()
# Out:
# 1    11
# 0     7
# dtype: int64

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# dtype: int64

# %%
df[df.SibSp == 0].Survived.value_counts()
# Out:
# 0    398
# 1    210
# dtype: int64

# %%
df[df.Parch == 2].Sex.value_counts().plot(kind = 'bar')

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %%
df[df.Sex == 'female'].Pclass.value_counts().plot(kind = 'bar')

# %%
df.Ticket.value_counts()
# Out:
# CA. 2343        7
# 347082          7
# 1601            7
# 347088          6
# CA 2144         6
# 3101295         6
# 382652          5
# S.O.C. 14879    5
# PC 17757        4
# 4133            4
# LINE            4
# 349909          4
# 347077          4
# W./C. 6608      4
# 113760          4
# ...
# STON/O 2. 3101273    1
# 345777               1
# STON/O 2. 3101274    1
# STON/O 2. 3101275    1
# 113794               1
# 2649                 1
# 374887               1
# 349213               1
# 349210               1
# 349242               1
# 349216               1
# 112052               1
# 315088               1
# 349215               1
# W./C. 14258          1
# Length: 681, dtype: int64

# %%
df[(df.Sex=='male')].Ticket.value_counts()
# Out:
# 1601            7
# 3101295         5
# S.O.C. 14879    5
# CA 2144         4
# LINE            4
# CA. 2343        4
# 382652          4
# 239853          3
# 230080          3
# 347088          3
# 2699            2
# 7534            2
# 17421           2
# 347082          2
# PC 17572        2
# ...
# PC 17760             1
# 244252               1
# STON/O 2. 3101275    1
# STON/O 2. 3101274    1
# 349254               1
# STON/O 2. 3101273    1
# 371060               1
# A/5. 10482           1
# A./5. 2152           1
# 347063               1
# 334912               1
# 2664                 1
# 113510               1
# 236171               1
# 367226               1
# Length: 519, dtype: int64
